# %%
import matplotlib.pyplot as plt

# %%
keys, vals = [], []
with open("../../output_firstletter/part-r-00000", "r") as file:
    for t in file:
        k, v = t.strip().split("\t")
        keys.append(k)
        vals.append(int(v))

# %%
plt.figure(figsize=(13, 5))
plt.bar(keys, vals)
plt.yscale("log")
plt.xlabel("Freq")
plt.ylabel("Letter")
plt.title("The Frequency of Letters present at the beginning of word")
plt.grid(color='r', linestyle='-', linewidth=1, axis="y", which="major")
plt.show()
